# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidSenseman/BIO3523/blob/main/BIO3523_Class_01_1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!-- BIO3523_Class_01_1:Rev 1 -->

# %% [markdown]
# ---------------------------
# **COPYRIGHT NOTICE:** This Jupyterlab Notebook is a Derivative work of [Jeff Heaton](https://github.com/jeffheaton) licensed under the Apache License, Version 2.0 (the "License"); You may not use this file except in compliance with the License. You may obtain a copy of the License at
#
# > [http://www.apache.org/licenses/LICENSE-2.0](http://www.apache.org/licenses/LICENSE-2.0)
#
# Unless required by applicable law or agreed to in writing, software distributed under the License is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied. See the License for the specific language governing permissions and limitations under the License.
#
# ------------------------

# %% [markdown]
# # **BIO 3523: Advanced Computational Biology**

# %% [markdown]
# ## **Module 1 : Getting Started with Hermes Agent**
#
# * Instructor: [David Senseman](mailto:David.Senseman@utsa.edu), [Department of Biology, Health and the Environment](https://sciences.utsa.edu/bhe/), [UT San Antonio](https://www.utsa.edu/)
#
# ### Class Content
#
# * **Class_01_1 : Course Overview and Getting an OpenRouter API Key**
# * Class_01_2 : Installing Hermes Agent
# * Class_01_3 : Connecting Hermes Agent to Discord
# * Class_01_4 : TBA
# * Class_01_5 : TBA
# * Class_01_6 : TBA

# %% [markdown]
# ## Google Colab Instructions
#
# Run next code cell to map this Colab lesson's folder /content/drive to your Google Drive. This will allow you keep a copy of this Colab notebook which is your course textbook.

# %%
# @title **Run this cell first**
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    Colab = True
    print("Note: Using Google CoLab")
    # !curl ipinfo.io
except:
    print("**WARNING**: Your GDrive is not mapped to /content/drive ")
    print("**WARNING**: Your work will not be saved!")
    Colab = False

# %% [markdown]
# You should see something _similar_ to the following output:
# ```text
# Mounted at /content/drive
# Note: Using Google CoLab
# {
#   "ip": "34.139.115.187",
#   "hostname": "187.115.139.34.bc.googleusercontent.com",
#   "city": "North Charleston",
#   "region": "South Carolina",
#   "country": "US",
#   "loc": "32.8546,-79.9748",
#   "org": "AS396982 Google LLC",
#   "postal": "29415",
#   "timezone": "America/New_York",
#   "readme": "https://ipinfo.io/missingauth"
# }
# ```

# %% [markdown]
# ## Test Your Keys
#
# Run the next cell to test whether your `myUTSA_ID` and your `BIO3523_Key` are correctly installed in your Colab Secrets. You will need to have both keys correctly installed in your Colab Secrets in order to submit your work for grading using Electronic Submission.

# %%
# @title Test Your Keys

from google.colab import userdata
import os

# Check if myUTSA_ID is properly loaded
try:
    # 1. Get the key from Secrets
    myUTSA_ID = userdata.get('myUTSA_ID')

    # 2. Set it as an environment variable
    os.environ['myUTSA_ID'] = myUTSA_ID

    # print("myUTSA_ID is loaded and environment variable set successfully!")
    print(f"myUTSA_ID: {myUTSA_ID}")

except Exception as e:
    print(f"Error loading myUTSA_ID: {e}")
    print("Please set your myUTSA_ID in Google Colab:")
    print("1. Go to Secrets in the left sidebar (key icon)")
    print("2. Create a new secret named 'myUTSA_ID'")
    print("3. Paste your myUTSA_ID and toggle 'Notebook access' on")

# Check if BIO3523 key is properly loaded
try:
    # 1. Get the key from Secrets
    BIO3523_KEY = userdata.get('BIO3523_KEY')

    # 2. Set it as an environment variable
    os.environ['BIO3523_KEY'] = BIO3523_KEY

    #print("BIO3523 key loaded and environment variable set successfully!")
    print(f"BIO3523_KEY: {BIO3523_KEY}")

except Exception as e:
    print(f"Error loading BIO3523 key: {e}")
    print("Please set your BIO3523 key in Google Colab:")
    print("1. Go to Secrets in the left sidebar (key icon)")
    print("2. Create a new secret named 'BIO3523_KEY'")
    print("3. Paste your BIO3523 key and toggle 'Notebook access' on")

# %% [markdown]
# If you have correctly installed both your `myUTSA ID` and your `BIO3523 Key` in your Colab Secrets, you should see something _similar_ to following but with your information:
# ```text
# myUTSA_ID: abc123
# BIO3523_KEY: BIO35233-F26-04-999-ABC-DEF
# ```
# However, if you see an error message, you will need to fix this problem before you can submit your lesson for grading. Ask your Instructor or TA for help if you can't resolve the problem yourself --- that's what they are here for, to help you with course problems.

# %% [markdown]
# # **Course Overview**

# %% [markdown]
# ## **Agentic AI**
#
# In the prerequisite course to this one, **_Introduction to Computational Biology_ (BIO1173)**, you were introduced to the concept of **Agentic AI**. Agentic AI refers to autonomous systems ("AI agents") capable of perceiving their environment, planning multi-step actions, using external tools, and executing tasks to achieve complex goals with minimal human intervention. In this course we focus on the use of **_personal_ AI agents** in your current study of biology, ecology and/or medicine. Perhaps more importantly, as time goes on you will find the skills that you develop in this course to be increasingly important in your professional life after you graduate from UT San Antonio.
#
# #### **OpenClaw - _The Rise of the Personal AI Agent_**
#
# While the application of agentic AI has been steadily growing for several years now, the idea that an individual should have their own personal AI agent is very new. On November 24, 2025, the Austrian developer Peter Steinberger launched a self-hosted personal tool using Anthropic's Claude API with messaging integration called **Clawdbot**. This project was shortly rebranded to **Moltbot** following trademark discussions regarding the similarity of "Clawd" to Anthropic's "Claude".  Then, on January 29, 2026, the name was offically changed to **OpenClaw** to reflect its model-agnostic, open-source foundation.
#
# As of this time, the main OpenClaw repository (openclaw/openclaw) has 384,000+ stars on GitHub. It experienced an unprecedented viral surge in early 2026—crossing 250,000 stars by early March—making it one of the fastest-growing open-source projects in GitHub history. OpenClaw is still extremely popular.
#
# #### **Hermes Agent - _A Better Alternative_**
#
# Instead of using OpenClaw, we will be using another personal AI agent for this course called **Hermes Agent**. Hermes Agent is an open-source, autonomous AI agent harness developed by **Nous Research**. Unlike traditional stateless chatbots or IDE-bound coding copilots, Hermes Agent is designed as an always-on, self-improving runtime that runs on your computer or laptop.
#
# ##### **Key Features of Hermes Agent**
# * **Closed Learning Loop:** The agent observes repeated multi-step tool interactions, turning successful workflows into reusable, self-improving procedural skills (supporting the open `agentskills.io` standard).
# * **Persistent Memory & Personalization:** Maintains long-term context and memory across sessions without needing context resets.
# * **Multi-Platform Access:** Connects directly to CLI, Telegram, Discord, Slack, WhatsApp, and 20+ other messaging channels through a single unified gateway.
# * **40+ Built-In Tools & MCP Support:** Includes web browsing, code execution, terminal access, and native Model Context Protocol (MCP) server integration.
#
# ---
#
# #### **Hermes Agent vs. OpenClaw**
#
# While both projects are model-agnostic, open-source, and self-hostable, they approach autonomous AI with fundamentally different philosophies:
#
# | Feature | OpenClaw | Hermes Agent |
# | :--- | :--- | :--- |
# | **Core Philosophy** | **Multi-agent control plane:** Designed for coordinating teams of specialized agents. | **Self-improving runtime:** Built for a single persistent agent that gets smarter over time. |
# | **Skill Management** | Uses explicitly defined, static, or marketplace-driven skills. | Dynamically synthesizes and refines skills from past execution patterns. |
# | **Primary Strength** | Complex multi-agent coordination and broad multi-channel governance. | Always-on background automation, cron jobs, and self-improving workflows. |
# | **Deployment Fit** | Larger setups requiring orchestration across multiple tools and agents. | Lightweight, inspectable, background server deployment (VPS, SSH, Serverless). |
#
# ---

# %% [markdown]
# ## **How Hermes Agent Works**
#
# Hermes Agent is one type of an **LLM harness**.  An LLM harness acts as the _operating system_ surrounding a large language model (LLM). Without a harness, a LLM is basically "a brain in a jar". The LLM (e.g. "ChatGPT") can think, but it can't really **_do_** anything with its thoughts. An AI agent, like Hermes Agent, **provides a body** for the brain, converting thoughts into physical actions.
#
# The software underlying Hermes Agent has the following 4 parts:
# 1. **Execution Loop**
# 2. **Context Routing**
# 3. **Tool Parsing**
# 4. **Memory Persistence**
#
# Together, these 4 parts allow any foundation model to function as your long-running, personal assistant.
#
# ```text
# +-----------------------------------------------------------------------+
# |                            HERMES HARNESS                             |
# |                                                                       |
# |   +-------------------+     +------------------+    +-------------+   |
# |   |  Multi-Platform   |     | Memory System    |    | Tool Engine |   |
# |   |  Gateway (Telegram|     | (FTS5 + SQLite + |    | (Bash, MCP, |   |
# |   |  Discord, CLI)    |     | Honcho User Model|    | Python RPC) |   |
# |   +---------+---------+     +--------+---------+    +------+------+   |
# |             |                        |                     |          |
# |             +-------------------+    |    +----------------+          |
# |                                 |    |    |                           |
# |                                 v    v    v                           |
# |                        +-----------------------+                      |
# |                        | Context Assembler     |                      |
# |                        | & Dynamic System      |                      |
# |                        | Prompt Generator      |                      |
# |                        +-----------+-----------+                      |
# +------------------------------------|----------------------------------+
# | (API Call / Local Inference)
# v
# +-----------------------+
# |     Raw LLM Engine    |
# | (OpenAI, vLLM, etc.)  |
# +-----------------------+
# ```
# #### **The Core Agent Loop (Observation-Action Cycle)**
#
# At its lowest level, the harness manages the event loop between the user, the environment, and the model:
#
# 1. **Input Interception:** Incoming messages from any interface (CLI, Telegram, Discord, Slack) are normalized into standard user turns.
# 2. **Context Assembly:** Before hitting the LLM, the harness injects relevant system prompts, active project context files, persistent user memory, and available tool definitions.
# 3. **Inference & Tool Parsing:** The LLM receives the prompt and emits either direct prose or structured tool calls. Hermes Agent intercepts these tool requests, executes them safely, and appends the result back into the prompt context.
# 4. **Execution Decision:** If the model returns tool calls, the harness recursively loops (running tools and feeding back stdout/stderr) until the model satisfies the objective or requests user input.
#
# ---
#
# #### **Dynamic Memory & The "Closed Learning Loop"**
#
# Standard LLM calls forget everything once the context window closes. Hermes Agent acts as a persistent layer by surrounding the LLM with three memory subsystems:
#
# * **Episodic Recall (FTS5 & Vector Search):** Past conversation logs are indexed locally in SQLite. The harness automatically pulls relevant historical snippets into current turns when related topics re-emerge.
# * **Agent Nudges:** The harness periodically interrupts the execution stream with system prompts ("nudges") directing the LLM to summarize key user facts, project states, or lessons learned into long-term storage.
# * **Self-Generated Skills (`agentskills.io`):** When the LLM successfully completes a complex, multi-step trajectory, the harness prompts it to synthesize the solution into a structured `SKILL.md` file. In future runs, the harness injects these custom skills as available tools.
#
# ---
#
# #### **Sandboxed Tool Execution Environments**
#
# An LLM cannot run shell commands or write files directly; it can only output text. The harness acts as the execution proxy:
#
# * **Backend Abstraction:** Hermes routes command execution through configurable backends—ranging from a local subshell to hardened Docker containers, remote SSH nodes, or cloud serverless backends (e.g., Daytona, Modal).
# * **Native Tool Integration & MCP:** Out of the box, the harness exposes 40+ native capabilities (web search, browser automation, file I/O) alongside support for Model Context Protocol (MCP) servers.
# * **Programmatic Execution (`execute_code`):** To avoid burning token budget on repetitive step-by-step tool turns, the harness allows the LLM to write Python scripts that invoke tools locally via RPC in a single inference cycle.
#
# ---
#
# #### **State & Context Management**
#
# Raw LLMs struggle when message histories exceed context limits or token costs spike. The harness handles the scaffolding:
#
# * **Context Compression:** The harness monitors token usage and transparently condenses old execution traces or tool outputs while preserving core facts.
# * **Sub-Agent Delegation:** When tasked with large parallel jobs, the main harness can spawn lightweight, isolated child instances with their own execution loops, minimizing context pollution in the main thread.

# %% [markdown]
# ## **You Need to Purchase an API Key**
#
# While consumer web apps like **Microsoft Copilot**, **ChatGPT**, or **Claude.ai** offer convenient, chat-based interfaces, they operate inside a "walled garden" designed primarily for manual, single-turn text interactions. Chat UIs require a human to manually open a browser tab, paste prompts, and click buttons. Copilot lives inside a locked browser or office suite window. A chat app is limited to built-in features provided by the vendor. Web interfaces enforce vendor-defined safety filters, UI layouts, and context truncation rules.
#
# To use an AI agent like Hermes Agent, you need to use an API key. An API key allows an agent harness to run **autonomously** in the background on a server—executing scheduled cron jobs, responding to webhook events, or triggering workflows without human intervention.
#
# An API key enables a local or remote agent harness to run native shell commands, modify local codebases, manage files, and interact directly with your system's terminal and developer tools. With an API key, the harness can connect to your databases, local APIs, and custom tools (via protocols like MCP), acting as an execution layer for your own private infrastructure. An API connection lets you configure your own custom context management, choose your system prompts, select exact model versions, and enforce strict data privacy policies.
#
# ### **Where to Get An API Key**
#
# OpenAI-compatible API keys that be plugged directly into Hermes Agent (`base_url` and `api_key` settings) are available from several cloud providers including:
#
# * **Google AI Studio:** Offers free and paid API keys for Gemini models (e.g., Gemini Flash) with up to 1 million tokens of context window.
# * **Groq:** Provides free and paid API keys for high-speed inference on open-weight models (like Llama 3.3 70B).
# * **OpenRouter:** Offers an API key that grants access to 20+ free routing endpoints (including models like Gemma, Nemotron, and Llama variants).
#
# If you already have your own, OpenAI-compatible API key, you are might be able to use it for your Hermes Agent, but it is not recommended. For example, some student who took BIO1173 might still have their Google API key. First, Hermes Agent doesn't naively support API keys from all sources. Perhaps more importantly, you might end up spending much more money for this course than you might want.
#
# The steps presented in the next section show how to get an API from a company called **OpenRouter**. After you have successfully setup your Hermes Agent using an OpenRouter API key, you are more than welcome to switch your API key and model.

# %% [markdown]
# ## **Getting an OpenRouter API Key**
#
# There are many ways that you can obtain an API Key to access LLM models. For this course, you will be using an API key from **OpenRouter**. OpenRouter is a popular AI model gateway and marketplace founded in 2023 by Alex Atallah (co-founder of OpenSea) and Louis Vichy. It acts as a single, unified interface for accessing hundreds of large language models from multiple providers through a single OpenAI-compatible API key. OpenRouter has a number of features that makes it especially attractive for this course including, but not limited to, access to **free models**.
#
# #### **Key Highlights & Features:**
#
# * **Universal API Access:** Rather than managing separate SDKs, accounts, and API keys for OpenAI, Anthropic, Google, Meta, Mistral, and open-weight model hosts, developers integrate OpenRouter once to access over 400+ models.
# * **Smart Model Routing:** The platform automatically handles failover, model availability, load balancing, and route optimization (e.g., routing to the fastest, cheapest, or highest-throughput provider available for a requested model).
# * **No Vendor Lock-In:** Developers can swap the underlying model used by their application by changing a single parameter string in their payload without altering their application logic.
# * **Unified Billing & Analytics:** Provides centralized token metering, spend limits, and cost tracking across all model calls in one dashboard.
# * **Public Benchmarks & Live Telemetry:** OpenRouter publishes real-time model usage leaderboards, pricing comparisons, and context window capabilities based on anonymized platform traffic

# %% [markdown]
# ## **YouTube Instructions for Getting Your OpenRouter API Key**
#
# Before you continue with this lesson, you should watch this `YouTube` tutorial on how to get an API key on OpenRouter.

# %%
# @title **How to get your OpenRouter key**
from IPython.display import HTML
video_id = "2FOg5_n9Dho?si=eDcbzM_HYN-8SLH1"
HTML(f"""
<iframe width="560" height="315"
  src="https://www.youtube.com/embed/{video_id}"
  title="YouTube video player"
  frameborder="0"
  allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture"
  allowfullscreen
  referrerpolicy="strict-origin-when-cross-origin">
</iframe>
""")

# %% [markdown]
# # **Using My Credit Card to buy an API Key?**
#
# A very legitimate question is
#
# >## **How much is this course going to cost me?**
#
# And my honest answer is I don't really know.
#
# I know that your API key will be your only additional cost associated with your BIO3523 course. You will **not** be asked to purchase any textbooks or access to any on-line resource like _Mastering Human A&P_  or Google _Colab Pro_.
#
# I also know you that **you** could easily spend **several thousand dollars** completing the lessons in this course -- if you aren't careful.
#
# Here is what I don't know. I don't know the **minimum amount of money** that you will need to spend on API charges to complete the 15 lessons in this course. My goal is keep the total costs under \$300 or about \$12.00 per lesson. If I find that API costs are getting above \$250, I will modify the lessons to reduce, over even eliminate any need to use an API key for the remainder of the course.
#
# There are 2 reasons that I can't tell you how much this course will cost. First, a course like this has never been taught before at UT San Antonio so there is no historical records. Second, and perhaps more importantly, how much you spend will depend largely on the choices **you** make. In theory, a clever student could finish this course with an API bill less than the cost of Starbucks coffee.
#
# ## **API Key Charges**
#
# When you use your API key, you are billed for "tokens in" and "tokens out". Different models have different costs, with the newest, most capable models, so-called **Frontier Models**, costing the most.
#
# For example, right now (Jul 24, 2026) Antropic's Frontier Model **Claude  Fable** costs \$10 for 1 million input tokens (\$10/M input tokens) and \$50 dollars for 1 million output token (\$50/M output tokens). OpenAI's new frontier model, **GPT-5.6 Sol** costs \$5/M input tokens and \$30/M output tokens.
#
# Both of these models are _very_ powerful and _very_ expensive. If some reason decide that you want to use `Claude Fable` or `GTP-5.6 Sol` for the brains of your Hermes Agent, your API charges could easily run into several hundreds of dollars for one lesson!.
#
# >##### **BOTTOM LINE: NEVER USE A FRONTIER MODEL IN THIS COURSE--unless you want to waste your money**
#
# Frontier AI models are the most advanced, large-scale general-purpose artificial intelligence systems available. They push the limits of technology using massive computing scale and multimodal data processing. There is **absolutely no reason to ever to use a Frontier Model in this course**. You will get the same answer from a "cheap" model for the kinds of problems that your Hermes Agent will need to solve in this course. So don't waste you money.

# %% [markdown]
# ## **"Burning Tokens"**
#
# As mentioned above, Claude Fable costs $10 for 1 million input tokens. A million input tokens may sound like a lot, but it isn't when it comes to using an AI Agent.
#
# Consider, for the moment what happens when you give a trivial prompt like **"Hi Hermes"**. The token consumption is _drastically_ different* from a standard ChatGPT or OpenRouter playground session.
#
# Because Hermes is an autonomous agent framework, every API call carries substantial system overhead (tool definitions, system instructions, memory files, and skill indexes) before the model processes your actual two-word query, "Hi Hermes".
#
# ---
#
# ### **Estimated Token Breakdown for "Hi Hermes"**
#
# #### **Input Tokens (~12,000 to 16,000 tokens**):
# * **Tool Schemas (JSON/XML):** **~8,000 – 10,000 tokens**
#   Hermes passes full schemas for all registered native tools (filesystem operations, web browsing, terminal execution, memory updates, subagents, etc.) on every request so the LLM knows how to invoke them.
# * **System Prompt & Base Rules:** **~2,000 – 3,000 tokens**
#   Contains core behavioral instructions, safety guardrails, output formatting standards, and instructions on how to structure tool calls.
# * **Skills Index (`## Skills`):** **~1,000 – 3,500 tokens**
#   The agent loads an index of installed skill definitions so it knows what capabilities it can dynamically pull in.
# * **Memory & User State (`SOUL.md`, `MEMORY.md`, `USER.md`):** **~500 – 1,500 tokens**
#   The agent's personality traits, saved memories across sessions, and user profile information.
# * **Your Message (`"Hi Hermes"`):** **~3 – 5 tokens**
#
# #### **Output Tokens (~10 to 50 tokens**):
# * Since "Hi Hermes" does not require executing any tools or bash commands, the LLM will recognize this as a simple greeting and bypass tool calls. However, a "thinking model" might output
# * **Agent Response:** A brief greeting like *"Hi Hermes"* can trigger your agent's response as shown in this example:
# --------------
# > _Reasoning...
#
#  >_Toggle content
#
#  >Thinking Process:
#
#
# >Analyze the User's Input: The user says "Hi Hermes".
# Identify the Intent: The user is initiating a conversation and addressing me by my name.
# Formulate the Response:
# Acknowledge the greeting.
# Maintain a warm and helpful tone.
# Keep it concise.
# Offer assistance.
# Drafting the response: "Hi there! How can I help you today?" or "Hello! What's on your mind?"
# Final Polish: "Hi there! How can I help you today?" is perfect. Simple, friendly, and ready to assist. Let's go with something similar. "Hello! How can I help you today?" is good. Let's add a bit of personality. "Hi! How can I help you today?" is simple and effective.
# Let's just say "Hi there! How can I help you today?" or "Hello! How can I assist you today?"
#
# >Wait, the prompt is "Hi Hermes", so I should respond to that.
# "Hi! How can I help you today?" is perfect.
#
# >Wait, I am Hermes. The user addressed me as Hermes. I will respond warmly.
# "Hi there! How can I help you today?" or "Hello! What can I do for you today?"
# ---
#
# This example consumed another **180 to 200 tokens**. However you should note that these are the much most expensive **output** tokens! If you were using a very expensive frontier model, you might have just spent \$10 saying "Hi Hermes".
#
# ---
#
# ### Summary Table
#
# | Direction | Token Count | Main Contributor |
# | :--- | :--- | :--- |
# | **Tokens IN (Prompt)** | **~13,000 – 15,000+ tokens** | Tool definitions, system rules, and loaded memory/skills |
# | **Tokens OUT (Completion)** | **~180 – 200 tokens** | Brief text greeting response |
#
# ---
#
# #### **Key Takeaways for Usage & Costs**
#
# **Prompt Caching is Critical:** If using providers with **Prompt Caching** enabled (like Anthropic, DeepSeek, or OpenRouter routes supporting cache write/read), the fixed ~14k system prompt gets cached. Subsequent turns in that session will only charge you a fraction of the cost for cached input tokens.
#
# **Why Free Tiers Fail Fast:** If a student tests a free API tier that limits requests to 4,000 or 8,000 input tokens per call, sending "Hello Hermes" will immediately trigger a context length truncation or API validation error before the model even reads the word "Hello".

# %% [markdown]
# ## **Inexpensive "Open-Weight" Models**
#
# In order to keep your API charges to a minimum, you should use a mixture of free and relatively inexpensive "open-weight" models. For example, DeepSeek **R1** is an older, Chinese openweight model that very capable. It costs \$0.80/M input tokens and \$0.80/M output tokens. Here is the OpenRouter page for DeepSeek R1;
#
# ![__](https://biologicslab.co/BIO3523/images/class_01/class_01_1_image03A.png)
#
#
# Read the **Effective Pricing** statement at the bottom which explains what you would acutally pay if you used this model with your Hermes Agent. For input tokens the real price is **\$0.799** for 1 million input tokens and **\$2.72** for 1 million output tokens.

# %% [markdown]
# ## **Free Models**
#
# OpenRouter usually offers a several **free models** at any given point in time. You are more than welcome to use any free model for your Hermes Agent. The name and number of free models change frequently. At the time of this writing (Jul 27, 2026), you could use Poolside's **Laguna S 2.1** for free. Here is the model's page on OpenRouter:
#
# ![__](https://biologicslab.co/BIO3523/images/class_01/class_01_1_image02A.png)
#
# Here the **Effective Pricing** is **\$0.000** for both input and output tokens.
#
# The good news is that most free models are extremely capable, Poolside's **Laguna S 2.1** being an excellent example. In many AI categories like "coding", "tool use", etc., Laguna S 2.1 is not far behind the current frontier models like Claude Fable. The bad news is that free access is always temporary and by the time you read this you will have to pay to use Laguna S 2.1. If history is any kind of guide, you will be able to find a few new free models available from OpenRouter when you need to find one for your Hermes Agent.

# %% [markdown]
# ## **Using Free Models with Hermes Agent**
#
# While free API tiers (like OpenRouter’s :free models or Hugging Face free inference) seem ideal for a college student budget, agentic frameworks like Hermes Agent operate very differently from standard chat interfaces. Because Hermes relies on continuous tool-calling loops, background memory, and multi-turn subagent tasks, relying on free-tier models introduces severe operational bottlenecks that make development frustrating.
#
# #### **Rapid Rate-Limit Exhaustion (429 Errors)**
#
# * **The Problem:** In a typical chat interface, one user prompt equals one API call. In Hermes Agent, a single user prompt triggers a multi-step execution loop: planning $\rightarrow$ tool call $\rightarrow$ tool output $\rightarrow$ reflection $\rightarrow$ final answer. A single task can generate 5 to 15 API requests under the hood.
# * **The Impact:** Free tiers on OpenRouter (typically capped at 20 requests/minute or 200 requests/day) hit rate limits halfway through a single multi-step task. The agent freezes mid-session or crashes with HTTP 429 errors.
#
#
# #### **Broken Tool & Function Calling ("Talks, But Does Nothing")**
#
# * **The Problem:** Hermes Agent relies on native JSON/XML function calling to execute shell commands, edit files, or browse the web. Many free-tier endpoints route to smaller or unoptimized models that lack robust tool-calling support.
# * **The Impact:** Free models often output raw tool JSON or XML tags as standard message text (e.g., <tool_call>{"name": "filesystem"}</tool_call>) instead of structuring it as a system API call. Hermes treats this as plain conversational text, leading to the common issue where the agent talks about creating a file or running a script, but never actually executes it.
#
# #### **Severe Context Window Capping**
#
# * **The Problem:** To keep hosting costs zero, free provider endpoints frequently cap input context windows (often to 4,096 or 8,192 tokens), even if the underlying model architecture supports much more.
# *  **The Impact:** Hermes injects substantial system instructions, memory files, skill sets, and tool definitions into every prompt. In a truncated context window, the agent quickly loses track of earlier context, forgets user instructions mid-task, or enters endless repetition loops.
#
# #### **High Latency, Cold Starts, and Unreliability**
#
# * **The Problem:** Free endpoints run on low-priority or queue-backed serverless infrastructure.
# * **The Impact:** Response latency can range from 10 to 30 seconds per turn due to cold starts. Furthermore, free endpoints suffer high rates of 502 Bad Gateway or 503 Service Unavailable errors during peak hours, breaking scheduled cron tasks or multi-agent workflows.
#
#
# Practical Comparison
# Feature / Factor | Free API Models (:free suffix) | Low-Cost OpenRouter API Models (e.g., DeepSeek, Qwen 2.5 72B, Llama 3.3)
# --- | --- | ---
# Tool Calling Reliability | Flaky; often outputs tool calls as plain text | Reliable native JSON function-calling support
# Rate Limits | Harsh per-minute / per-day caps | Capped only by account credit balance
# Context Window | Capped/truncated by host (4k–8k) | Full context window available (32k–128k+)
# Agent Multi-Step Task Success | Low (~20–40%) due to rate limits & context loss | High (~90%+)
# Estimated Student Cost | $0.00 | ~$0.10 to $0.50 per week for active dev work
#
# # **Recommended Strategy**
#
# **Use Free Tiers for Setup Cursory Testing:** Use OpenRouter free models or NVIDIA NIM credits solely to verify CLI setup and test basic prompt-response formatting.
#
# **Deposit \$10 on OpenRouter for Real Agent Work:** Switching to a low-cost, high-performing model (like **Qwen 2.5 72B**, **Llama 3.3 70B**, or **DeepSeek**) on OpenRouter costs fractions of a cent per 1,000 tokens. A \$10 credit balance typically lasts weeks of active agent development while eliminating `429` rate limits and broken tool calls.

# %% [markdown]
# ## **Bad Things Can Happen to Students!**
#
# Here are 4 real examples of what can happen to students when they used their API key incorrectly:
#
# #### 1. **The \$10,000+ Bill (Reddit/Community Stories)**
#    - **What Happened:** A computer science student built a personal project (e.g., a chatbot, a game, or an auto-scaling service) using a free-tier API that had no hard spending cap. Due to a bug in their code (an infinite loop or a recursive call), the API was called thousands of times per second.
#    - **Result:** The bill escalated to **$10,000–$15,000** within days. Many platforms (like AWS, Azure, or older versions of OpenAI) required manual payment or had grace periods, but the **_student was still liable_**.
#
# #### 2. **The "Infinite Loop" Incident (OpenAI/Dall-E)**
#    - **What Happened:** A student attempted to generate images using DALL-E 2 API for a school project. Their code had a bug where it repeatedly triggered image generation without a proper exit condition.
#    - **Result:** Bill reached **~$2,000** in a single night. OpenAI customer support often helps in such cases if the user is a student and the issue is clearly a bug, but **not all providers are forgiving**.
#
# #### 3. **AWS SageMaker/Bedrock Accidents**
#    - **What Happened:** Students using AWS for machine learning projects often leave GPU instances running or set up auto-scaling groups that spiral out of control when connected to LLM APIs.
#    - **Result:** Bills of **\$5,000–** **\$20,000** are not uncommon in university labs or **personal student accounts**.
#
#
# #### 4. **The "Hugging Face" Inference API Incident**
#    - **What Happened:** A student used a public endpoint for a large model (like LLaMA or **Hermes**) via a third-party provider. The endpoint was left exposed without authentication, and bots started spamming requests.
#    - **Result:** Bill exceeded **\$3,000** in 48 hours.
#
# ------------
#
# >## **----- READ THIS CAREFULLY -----**
#
# >## **You will be using _your_ own credit card to pay for _your_ own API Key.**
#
# >#### **If you "screw up", you will have to pay for _your_ mistakes out of _your_ own pocket!**
# -------------------
#
# An important aspect of this course is to help you learn how to use an API Key securely so bad things **don't happen** to you. Think about this course as a **Learn to Drive** course you may have taken in High School. Instead of learning how to drive safely on a street in your car, this course is designed how to teach how to drive safely on the AI information highway. You will have nothing to worry about--provided you are careful and follow the rules.

# %% [markdown]
# ## **AGAIN: Recommended Strategy for Students**
#
# **Use Free Tiers for Setup Cursory Testing:** Use OpenRouter free models or NVIDIA NIM credits solely to verify CLI setup and test basic prompt-response formatting.
#
# **Deposit \$10 on OpenRouter for Real Agent Work:** Switching to a low-cost, high-performing model (like **Qwen 2.5 72B**, **Llama 3.3 70B**, or **DeepSeek**) on OpenRouter costs fractions of a cent per 1,000 tokens. A \$10 credit balance typically lasts weeks of active agent development while eliminating `429` rate limits and broken tool calls.

# %% [markdown]
# ## **Get your OpenRouter API Key**
#
# For  `Class_01_1`, you need to obtain an API key that you will use in the next lesson to install Hermes Agent. Even if you later want to use a different API key, you still need to obtain a valid OpenRouter API key for this lesson.
#
# Below are the steps that you need to follow to obtain your OpenRouter API key:
#
# ---------
# **Step 1:** Go to the OpenRouter web page: https://openrouter.ai/
#
# ---------
#
# **Step 2:** Sign Up
#
# ![__](https://biologicslab.co/BIO3523/images/class_01/class_01_1_image05A.png)
#
# -------------
# **Step 3:** Click on `Get API Key`
#
# ![__](https://biologicslab.co/BIO3523/images/class_01/class_01_1_image04A.png)
#
# -----------
# **Step 4:** Create a new API key
#
# ![__](https://biologicslab.co/BIO3523/images/class_01/class_01_1_image06A.png)
#
# ---------
# **Step 5:** Specify a Credit Limit of $10
#
# ![__](https://biologicslab.co/BIO3523/images/class_01/class_01_1_image07A.png)
#
# ------------
# **Step 6:** Make a Copy of Your API key
#
# ![__](https://biologicslab.co/BIO3523/images/class_01/class_01_1_image08A.png)
#
# ### **EXTREMELY IMPORTANT**
#
# To save your API key must use a **text editor**, _not_ a wordprocessor. If you are using a Windows laptop or computer, your text editor app is called **Notepad**. If you are using a Mac, your text editor is called **TextEdit**.
#
# Be careful not to let anyone see your OpenRouter API key. If you think your API key has been compromised, immediately go to OpenRouter to the API Keys page and delete your key. You can then generate a new key without charge.

# %% [markdown]
# ## **If You Need Help--Come to Class!**
#
# Don't worry if something goes wrong and you can't figure out how to get your API key. That's exactly the purpose of our class meetings. Always make sure you bring your laptop to class.

# %% [markdown]
# ## **Exercise 1: Verify Your API Key**
#
# Your grade for `Class_01_1` is simply based on whether or not you have obtained a valid OpenRouter API key.
#
# The code in the next cell will verify your API key from OpenRouter.
#
# When you run the code, a textbox will appear. Use your text editor to paste your OpenRouter API key into the textbox. To do this, copy your your key from your text file using your text editor. If you are using a Windows machine, your text editor is called **Notepad**. If you are using a Mac, your text editor is called **TextEdit**. Once you have copied your key to your computer's clipboard, place your cursor in the reponse box and hit **`CTRL-V`** (Windows) or **`CMD-V`** (Mac) to paste the number into the box. After you have pasted your API key, you should see this image:
#
# ![__](https://biologicslab.co/BIO3523/images/class_01/class_01_1_image10A.png)
#
# While your cursor is still inside the input box, hit **`Enter`** to run the rest of the code.
#
# To maintain security, you will **not** be able to see your code as it is being entered.
#
# **IMPORTANT**
#
# You should know that the your API key is _immediately_ destroyed after it has been checked, in order to maintain your key's security. No copy of your key is kept on the course file server.

# %%
# @title Exercise 1: Verify Your API Key

import re
import gc
import hashlib
from getpass import getpass
from IPython.display import clear_output, Image, display

# ── INPUT SECTION ──────────────────────────────────────────────────
api_key_ex = getpass("Use CTRL-V or CMD-V to paste API key here and hit Enter: ")
# ─────────────────────────────────────────────────────────────────

# Compute and print MD5 hash of the API key
md5_hash = hashlib.md5(api_key_ex.encode("utf-8")).hexdigest()
print("MD5 hash of your API key:", md5_hash)

# Scan key
pattern_ex = re.compile(r'^sk-or-v1-[a-f0-9]{64}$')
stripped_key_ex = api_key_ex.strip()
is_valid_ex = bool(pattern_ex.match(stripped_key_ex))

if is_valid_ex:
  print("Your API key is Valid")
  display(Image(url="https://biologicslab.co/BIO3523/images/class_01/congratulations-congrats.gif"))
else:
  print("Your API Key is not Valid. \nPlease try again.\n")
  print("Hints:")
  print("Copy-and-paste your API Key from your text file into the entry box and hit Enter.")
  print("If you are still having problems, please ask your Instructor for help.")

# %% [markdown]
# If the code is correct, you should see the following output:
# ```text
# Use CTRL-V or CMD-V to paste API key here and hit Enter: ··········
# MD5 hash of your API key: 5f1f2d75c22a12adb79fff8427061626
# Your API key is VALID
# ```
# ![__](https://biologicslab.co/BIO3523/images/class_01/congratulations-congrats.gif)

# %% [markdown]
# If your output says your API key is not Valid, you will need to repeat **Exercise 1** until you resolve this issue. Ask your Instructor or TA for help if you can't resolve the issue yourself.

# %% [markdown]
# -------------------
#
# ## **Can Someone Steal My API Key from the MD5 Hash?**
#
# The short answer is no—an MD5 hash cannot be directly reversed to recover your API key. The **MD5 hash algorithm** is a one-way cryptographic function that transforms any input into a fixed 128-bit digest. The reason you cannot regenerate the original text from this hash is that the process is inherently **lossy**. During hashing, the algorithm compresses the data through a series of bitwise operations and modular additions that discard information, mapping an effectively infinite range of possible inputs onto a finite output space.
#
# Because multiple different inputs can produce the same hash (a collision), and because the original byte sequence is mathematically scrambled and truncated, the specific information required to reconstruct the original text is simply no longer present in the final output. In essence, the hash is a fingerprint of the data, not an encrypted version of it—the transformation destroys the source data, making it computationally infeasible to reverse the process.
#
# **NOTE: Since a particular API key always produces the _same_ hash value, it is easy to tell if two students submit the _same_ API key in this lesson.**
#
# --------------

# %% [markdown]
# # **Electronic Submission**
#
# When you run the code in the cell below, it will grade your Colab notebook and tell you your pending grade as it currently stands. You will be given the choice to either submit your notebook for final grading or the option to continue your work on one (or more) Exercises.
#
# Grant Access to your Colab Secrets if you are asked to do so.

# %%
# @title  Electronic Submission

import urllib.request
import ssl
import time

url = "https://biologicslab.co/BIO3523/backend_code/validate.py?v=" + str(time.time())
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
req = urllib.request.Request(
    url,
    headers={
        "Cache-Control": "no-cache, no-store, must-revalidate",
        "Pragma": "no-cache",
        "Expires": "0"
    }
)
with urllib.request.urlopen(req, context=ctx) as r:
    exec(r.read().decode("utf-8"))
main()
